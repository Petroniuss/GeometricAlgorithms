# %% [markdown]
# # Laboratorium 1

# %% [markdown]
# ### Konfiguracja

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.collections as mcoll
import matplotlib.colors as mcolors
import json as js

# %% [markdown]
# ### Interfejsy
#
# [Dostępne kolory](https://matplotlib.org/3.1.1/gallery/color/named_colors.html)
#
# [Dostępne znaczniki punktów](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)

# %%
class PointsCollection:
    def __init__(self, points = [], color = None, marker = None):
        self.points = np.array(points)
        self.color = color
        self.marker = marker
        
class LinesCollection:
    def __init__(self, lines = [], color = None):
        self.color = color
        self.lines = lines
        
    def add(self, line):
        self.lines.append(line)
        
    def get_collection(self):
        if self.color:
            return mcoll.LineCollection(self.lines, [mcolors.to_rgba(self.color)] * len(lines))
        else:
            return mcoll.LineCollection(self.lines)

class Plot:
    def __init__(self, points=[], lines=[], json = None):
        if json is None:
            self.points = points
            self.lines = lines
        else:
            self.points = [PointsCollection(pointsCol) for pointsCol in js.loads(json)["points"]]
            self.lines = [LinesCollection(linesCol) for linesCol in js.loads(json)["lines"]]
            
    def draw(self):
        ax = plt.axes()
        for collection in self.points:
            if collection.points.size > 0:
                ax.scatter(*zip(*collection.points), c=collection.color, marker=collection.marker)
        for collection in self.lines:
            ax.add_collection(collection.get_collection())
        ax.autoscale()
        plt.draw()
        
    def toJSON(self):
        return js.dumps({"points": [pointCol.points.tolist() for pointCol in self.points], 
                          "lines":[linesCol.lines for linesCol in self.lines]})

# %% [markdown]
# ### Przykład użycia

# %%
# %matplotlib notebook

plot = Plot([PointsCollection([(1, 2), (3, 1.5), (2, -1)]), 
             PointsCollection([(5, -2), (2, 2), (-2, -1)], color = 'green', marker = "^")], 
            [LinesCollection([[(-1,2),(-2,3)]])])
plot.draw()
# Out:
# <div id='85ad4682-de2f-4592-a7ca-953f1900b870'></div>

# %% [markdown]
# ### Rozwiązanie

# %%
# %matplotlib notebook

from random import random, choice
from math import sin, cos, sqrt
from enum import Enum, auto
import math

signs = [-1, 1]

# %%
def generate_points_within_range(count, max):
    points = [(0.0, 0.0)] * count
    
    for i in range(count):    
        x = random() * max * choice(signs)
        y = random() * max * choice(signs)
        
        points[i] = (x, y)
        
    return points

def generate_points_a():
    return generate_points_within_range(10 ** 5, 10 ** 3)

def generate_points_b():
    return generate_points_within_range(10 ** 5, 10 ** 14)

# %%
def generate_points_c():
    radius = 100.0
    count = 1000
    points = [(0.0, 0.0)] * count
    
    for i in range(count):
        t = random()
        
        x = cos(2 * math.pi / t)
        y = sin(2 * math.pi / t)
        
        points[i] = (x * radius, y * radius)
    
    return points

# %%
def generate_points_d():
    count = 1000
    max = 1000
    
    a = (-1.0, 0.0)
    b = (1.0, 0.1)
    
    vector = (b[0] - a[0], b[1] - a[1])
    vector_len = sqrt(vector[0] ** 2 + vector[1] ** 2)
    normalized_vector = (vector[0] / vector_len, vector[1] / vector_len)
    
    points = [(0.0, 0.0)] * count
    
    for i in range(count):
        scale = random() * max * choice(signs)
        points[i] = (normalized_vector[0] * scale, normalized_vector[1] * scale)
    
    return points

# %%
# %matplotlib inline

points = generate_points_a()

plot = Plot([PointsCollection(points)])
plot.draw()

# %%
def det_1(a, b, c):
    return det2x2(b, c) - det2x2(a, c) + det2x2(a, b)
    
def det_2(a, b, c):
    return (a[0] - c[0]) * (b[1] - c[1]) - (a[1] - c[1])*(b[0] - c[0])

def det2x2(a, b):
    return (a[0]*b[1]) - (a[1]*b[0])

# %%
class Orientation(Enum):
    LEFT = auto()
    RIGHT = auto()
    COLLINEAR = auto()

# %%
def classify_point(c, epsilon, det):
    a = (-1.0, 0.0)
    b = (1.0, 0.1)
    
    determinant = det(a, b, c)
    orientation = Orientation.COLLINEAR
    
    if determinant > epsilon:
        orientation = Orientation.LEFT
    elif determinant < -epsilon:
        orientation = Orientation.RIGHT
    
    return orientation

# %%
def classify(points, epsilon, det):
    
    left, collinear, right = [], [], []
    
    for point in points:
        orientation = classify_point(point, epsilon, det)
        
        if orientation == Orientation.LEFT:
            left.append(point)
        elif orientation == Orientation.RIGHT:
            right.append(point)
        else:
            collinear.append(point)

    return (left, collinear, right)

# %%
epsilon_0 = 1
epsilon_1 = 10 ** (-3)
epsilon_2 = 10 ** (-6)
epsilon_3 = 10 ** (-9)

# %%
# %matplotlib notebook

def show_results(points, epsilon, det):
    (left, collinear, right) = classify(points, epsilon, det)

    plot = Plot([
        PointsCollection(left),
        PointsCollection(right, color='red'),
        PointsCollection(collinear, color='green')])
    
    print("Classified LEFT: {0} \nClassified RIGHT: {1} \nClassified COLLINEAR: {2}"
          .format(len(left), len(right), len(collinear)))

    plot.draw()

# %%
### Classification of set A
points_a = generate_points_a()

# %%
# %matplotlib notebook

show_results(points_a, epsilon_0, det_1)
# Out:
# Classified LEFT: 49948
# Classified RIGHT: 49994
# Classified COLLINEAR: 58
# <div id='b40c2054-92f2-49dd-9fd8-731cdf68f38c'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_1, det_1)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='d10737e8-5ccd-4a92-a769-b94ece74c938'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_1, det_2)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='d56690ff-a3ec-49fb-80e4-91d6db85a8bc'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_2, det_1)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='e180d09b-5bbd-4482-92d8-92bb83ec3cfa'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_2, det_2)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='510d6d24-edb3-43d0-8ba2-b68cc79a7b7f'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_3, det_1)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='1dbd2cf2-e07a-477b-9fae-70a4ae1dc939'></div>

# %%
# %matplotlib notebook

show_results(points_a, epsilon_3, det_2)
# Out:
# Classified LEFT: 49974
# Classified RIGHT: 50026
# Classified COLLINEAR: 0
# <div id='ec6be6c1-eb83-498b-9a17-4f49331b2b5c'></div>

# %%
### Classification of set B

points_b = generate_points_b()

# %%
# %matplotlib notebook

show_results(points_b, epsilon_0, det_1)
# Out:
# Classified LEFT: 50062
# Classified RIGHT: 49938
# Classified COLLINEAR: 0
# <div id='3c44a523-7c0d-4c71-8d10-2b934311c156'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_1, det_1)
# Out:
# Classified LEFT: 50062
# Classified RIGHT: 49938
# Classified COLLINEAR: 0
# <div id='27acbced-727c-4fb2-9056-2b6e3e05396f'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_1, det_2)
# Out:
# Classified LEFT: 50057
# Classified RIGHT: 49937
# Classified COLLINEAR: 6
# <div id='28593875-4606-49a9-b3d2-6219f74da3ba'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_2, det_1)
# Out:
# Classified LEFT: 50062
# Classified RIGHT: 49938
# Classified COLLINEAR: 0
# <div id='c4a76f71-4e9c-4ff5-b7d1-8fc684d86149'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_2, det_2)
# Out:
# Classified LEFT: 50057
# Classified RIGHT: 49937
# Classified COLLINEAR: 6
# <div id='1d02e97b-11ff-4d1a-a82c-1e648d2ac0c8'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_3, det_1)
# Out:
# Classified LEFT: 50062
# Classified RIGHT: 49938
# Classified COLLINEAR: 0
# <div id='7bf68eb4-6968-4b02-9da1-056ebf72b90d'></div>

# %%
# %matplotlib notebook

show_results(points_b, epsilon_3, det_2)
# Out:
# Classified LEFT: 50057
# Classified RIGHT: 49937
# Classified COLLINEAR: 6
# <div id='238d2147-984b-4be3-a711-f480462bc0d6'></div>

# %%
### Classification of set C

points_c = generate_points_c()

# %%
# %matplotlib notebook

show_results(points_c, epsilon_0, det_1)
# Out:
# Classified LEFT: 613
# Classified RIGHT: 380
# Classified COLLINEAR: 7
# <div id='843b079f-b18f-4cb7-a991-3def60135d02'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_0, det_1)
# Out:
# Classified LEFT: 613
# Classified RIGHT: 380
# Classified COLLINEAR: 7
# <div id='ac1f5cd0-bc9e-4b0f-a45d-5f2c17fa6e2b'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_1, det_1)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='e8f5bf3e-7fa9-448d-9b7e-432411383eff'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_1, det_2)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='535b9919-811f-4937-a7a8-3e6e4a8265a4'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_2, det_1)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='afe90ac1-b338-46f2-8fb4-6d7ed4eee710'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_2, det_2)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='75294af3-c3a3-4e2e-8c97-f2c6a037a92e'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_3, det_1)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='bf9817a9-b772-4bde-85a0-a227ecefb75c'></div>

# %%
# %matplotlib notebook

show_results(points_c, epsilon_3, det_2)
# Out:
# Classified LEFT: 618
# Classified RIGHT: 382
# Classified COLLINEAR: 0
# <div id='8ae07b20-3bbf-4998-bbc1-ef088cf1e947'></div>

# %%
### Classification os set D

points_d = generate_points_d()

# %%
# %matplotlib notebook

show_results(points_d, epsilon_0, det_1)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 0
# Classified COLLINEAR: 1000
# <div id='3f09a501-93f4-4807-9415-b076d5c2d4e1'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_1, det_1)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='dc18dad7-2da4-4c50-9097-f4dc58568f59'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_1, det_2)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='75fed35a-c9dc-4ac3-a49a-e314a90ed4f8'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_2, det_1)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='9a7ce1aa-a93e-4a4b-a9aa-9af7aba7eb6d'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_2, det_2)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='84ca5b29-c4b4-49f3-9b03-31c97d081e30'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_3, det_1)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='c74fefd2-a320-4313-b1f0-1ce6ac8c8e36'></div>

# %%
# %matplotlib notebook

show_results(points_d, epsilon_3, det_2)
# Out:
# Classified LEFT: 0
# Classified RIGHT: 1000
# Classified COLLINEAR: 0
# <div id='616a9eff-840e-4785-9295-fe94c83ba935'></div>
